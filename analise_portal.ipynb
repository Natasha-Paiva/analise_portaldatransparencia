# %%
import pandas as pd
pd.set_option("display.max_columns", None)
caminho_dados = "/content/drive/MyDrive/Analise_Asimov/2024_Viagem.csv"
df_viagens = pd.read_csv(caminho_dados, encoding="Windows=1252", sep=";")

df_viagens
# Out:
#         Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                  18831091                 000011/24
# 1                                  18831495                 000001/24
# 2                                  18831777                 000002/24
# 3                                  18831821                 000003/24
# 4                                  19177818              000001/24-1C
# ...                                     ...                       ...
# 792808                           2024001911             Sem informaçã
# 792809                           2024001912             Sem informaçã
# 792810                           2024001938             Sem informaçã
# 792811                           2024001946             Sem informaçã
# 792812                           2024001948             Sem informaçã
#
#              Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0           Realizada            NÃO                Sem informação
# 1           Realizada            NÃO                Sem informação
# 2           Realizada            NÃO                Sem informação
# 3           Realizada            NÃO                Sem informação
# 4           Realizada            SIM         Inclusão das diárias.
# ...               ...            ...                           ...
# 792808      Realizada            NÃO                Sem informação
# 792809      Realizada            NÃO                Sem informação
# 792810  Não realizada            NÃO                Sem informação
# 792811      Realizada            NÃO                Sem informação
# 792812      Realizada            NÃO                Sem informação
#
#         Código do órgão superior  \
# 0                          26000
# 1                          26000
# 2                          26000
# 3                          26000
# 4                          26000
# ...                          ...
# 792808                     25201
# 792809                     25201
# 792810                     25201
# 792811                     25201
# 792812                     25201
#
#                                    Nome do órgão superior  \
# 0                                  Ministério da Educação
# 1                                  Ministério da Educação
# 2                                  Ministério da Educação
# 3                                  Ministério da Educação
# 4                                  Ministério da Educação
# ...                                                   ...
# 792808  Banco Central do Brasil - Orçamento Fiscal e S...
# 792809  Banco Central do Brasil - Orçamento Fiscal e S...
# 792810  Banco Central do Brasil - Orçamento Fiscal e S...
# 792811  Banco Central do Brasil - Orçamento Fiscal e S...
# 792812  Banco Central do Brasil - Orçamento Fiscal e S...
#
#         Código órgão solicitante  \
# 0                          26425
# 1                          26274
# 2                          26274
# 3                          26274
# 4                          26271
# ...                          ...
# 792808                     25201
# 792809                     25201
# 792810                     25201
# 792811                     25201
# 792812                     25201
#
#                                    Nome órgão solicitante    CPF viajante  \
# 0       Instituto Federal de Educação, Ciência e Tecno...  ***.405.257-**
# 1             Fundação Universidade Federal de Uberlândia  ***.587.016-**
# 2             Fundação Universidade Federal de Uberlândia  ***.587.016-**
# 3             Fundação Universidade Federal de Uberlândia  ***.587.016-**
# 4                       Fundação Universidade de Brasília  ***.626.601-**
# ...                                                   ...             ...
# 792808  Banco Central do Brasil - Orçamento Fiscal e S...  ***.902.438-**
# 792809  Banco Central do Brasil - Orçamento Fiscal e S...  ***.697.505-**
# 792810  Banco Central do Brasil - Orçamento Fiscal e S...  ***.827.438-**
# 792811  Banco Central do Brasil - Orçamento Fiscal e S...  ***.425.230-**
# 792812  Banco Central do Brasil - Orçamento Fiscal e S...  ***.865.368-**
#
#                                     Nome  \
# 0             RICARDO DOS SANTOS PEREIRA
# 1               LETICIA SANCHEZ FERREIRA
# 2               LETICIA SANCHEZ FERREIRA
# 3               LETICIA SANCHEZ FERREIRA
# 4        VIRGINIA MARIA VASCONCELOS LEAL
# ...                                  ...
# 792808            NAGEL LISANIAS PAULINO
# 792809  EDSON BROXADO DE FRANCA TEIXEIRA
# 792810          GABRIEL MURICCA GALIPOLO
# 792811    GILNEU FRANCISCO ASTOLFI VIVAN
# 792812       Nilton Jose Schneider David
#
#                                         Cargo Função Descrição Função  \
# 0       PROFESSOR ENS BASICO TECN TECNOLOGICO     -1   Sem informação
# 1            PROFESSOR DO MAGISTERIO SUPERIOR     -1   Sem informação
# 2            PROFESSOR DO MAGISTERIO SUPERIOR     -1   Sem informação
# 3            PROFESSOR DO MAGISTERIO SUPERIOR     -1   Sem informação
# 4            PROFESSOR DO MAGISTERIO SUPERIOR     -1   Sem informação
# ...                                       ...    ...              ...
# 792808              ANALISTA DO BANCO CENTRAL     -1   Sem informação
# 792809              ANALISTA DO BANCO CENTRAL     -1   Sem informação
# 792810               DIRETOR DO BANCO CENTRAL     -1   Sem informação
# 792811              ANALISTA DO BANCO CENTRAL     -1   Sem informação
# 792812                                    NaN     -1   Sem informação
#
#        Período - Data de início Período - Data de fim  \
# 0                    23/02/2024            25/02/2024
# 1                    18/01/2024            22/01/2024
# 2                    29/02/2024            04/03/2024
# 3                    11/04/2024            15/04/2024
# 4                    29/01/2024            06/02/2024
# ...                         ...                   ...
# 792808               16/12/2024            16/12/2024
# 792809               17/12/2024            18/12/2024
# 792810               26/12/2024            27/12/2024
# 792811               29/12/2024            31/12/2024
# 792812               30/12/2024            30/12/2024
#
#                           Destinos  \
# 0                    Rio Branco/AC
# 1                     São Paulo/SP
# 2                     São Paulo/SP
# 3                     São Paulo/SP
# 4       Lille/França, Paris/França
# ...                            ...
# 792808              Sem informação
# 792809              Sem informação
# 792810              Sem informação
# 792811              Sem informação
# 792812              Sem informação
#
#                                                    Motivo Valor diárias  \
# 0       Ministrar a disciplina de Conceitos e Aplicaçõ...        929,18
# 1       Participação nas atividades do ESTAGIO DE CAPA...          0,00
# 2       Participação nas atividades do ESTAGIO DE CAPA...          0,00
# 3       Participação nas atividades do ESTAGIO DE CAPA...          0,00
# 4       Programação dos eventos que a Professora irá p...      14176,38
# ...                                                   ...           ...
# 792808  Participar, como palestrante, no evento '1 ano...        262,05
# 792809  Assessorar o Diretor de Fiscalização e cumprir...       1204,09
# 792810                        Cumprir agenda em Brasília.          0,00
# 792811  Suspensão das férias do servidor por motivo de...          0,00
# 792812                        Cumprir agenda em Brasília.        400,00
#
#        Valor passagens Valor devolução Valor outros gastos
# 0                 0,00            0,00                0,00
# 1                 0,00            0,00                0,00
# 2                 0,00            0,00                0,00
# 3                 0,00            0,00                0,00
# 4              6892,31            0,00                0,00
# ...                ...             ...                 ...
# 792808            0,00            0,00                0,00
# 792809         4044,69            0,00                0,00
# 792810            0,00            0,00                0,00
# 792811         5562,82            0,00                0,00
# 792812         3760,62            0,00                0,00
#
# [792813 rows x 22 columns]

# %%
df_viagens[["Valor diárias", "Valor passagens"]]

df_viagens["Valor diárias"] + df_viagens["Valor passagens"]

df_viagens["Valor diárias"] = df_viagens["Valor diárias"].str.replace(",", ".").astype(float)
df_viagens["Valor passagens"] = df_viagens["Valor passagens"].str.replace(",", ".").astype(float)
df_viagens["Valor devolução"] = df_viagens["Valor devolução"].str.replace(",", ".").astype(float)
df_viagens["Valor outros gastos"] = df_viagens["Valor outros gastos"].str.replace(",", ".").astype(float)

df_viagens["Valor passagens"]
# Out:
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4         6892.31
#            ...
# 792808       0.00
# 792809    4044.69
# 792810       0.00
# 792811    5562.82
# 792812    3760.62
# Name: Valor passagens, Length: 792813, dtype: float64

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0           929.18
# 1             0.00
# 2             0.00
# 3             0.00
# 4         21068.69
#             ...
# 792808      262.05
# 792809     5248.78
# 792810        0.00
# 792811     5562.82
# 792812     4160.62
# Length: 792813, dtype: float64

# %%
df_viagens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792813 entries, 0 to 792812
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Identificador do processo de viagem  792813 non-null  int64
#  1   Número da Proposta (PCDP)            792813 non-null  object
#  2   Situação                             792813 non-null  object
#  3   Viagem Urgente                       792813 non-null  object
#  4   Justificativa Urgência Viagem        792590 non-null  object
#  5   Código do órgão superior             792813 non-null  int64
#  6   Nome do órgão superior               792813 non-null  object
#  7   Código órgão solicitante             792813 non-null  int64
#  8   Nome órgão solicitante               792813 non-null  object
#  9   CPF viajante                         661166 non-null  object
#  10  Nome                                 792813 non-null  object
#  11  Cargo                                485759 non-null  object
#  12  Função                               792813 non-null  object
#  13  Descrição Função                     792810 non-null  object
#  14  Período - Data de início             792813 non-null  object
#  15  Período - Data de fim                792813 non-null  object
#  16  Destinos                             792813 non-null  object
#  17  Motivo                               792812 non-null  object
#  18  Valor diárias                        792813 non-null  float64
#  19  Valor passagens                      792813 non-null  float64
#  20  Valor devolução                      792813 non-null  float64
#  21  Valor outros gastos                  792813 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 133.1+ MB

# %%
df_viagens["Valor diárias"] + df_viagens["Valor passagens"]
# Out:
# 0           929.18
# 1             0.00
# 2             0.00
# 3             0.00
# 4         21068.69
#             ...
# 792808      262.05
# 792809     5248.78
# 792810        0.00
# 792811     5562.82
# 792812     4160.62
# Length: 792813, dtype: float64
